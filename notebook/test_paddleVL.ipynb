# %%
import paddle
paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# PaddlePaddle works well on 1 CPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.
# /Users/tak/Business/Upstage/test-ocr-models/.venv/lib/python3.12/site-packages/paddle/pir/math_op_patch.py:219: UserWarning: Value do not have 'place' interface for pir graph mode, try not to use it. None will be returned.
#   warnings.warn(

# %%
import fitz
from paddleocr import PaddleOCRVL

# モデル初期化
pipeline = PaddleOCRVL()

data_path = "../data_20251016/20250915_業務日報.pdf"
pdf = fitz.open(data_path)
# 画像に変換
img = pdf[0].get_pixmap()
# ドキュメント処理
output = pipeline.predict(img)
# Out:
# Creating model: ('PP-DocLayoutV2', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/tak/.paddlex/official_models/PP-DocLayoutV2`.
# Creating model: ('PaddleOCR-VL-0.9B', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/tak/.paddlex/official_models/PaddleOCR-VL`.
# Loading configuration file /Users/tak/.paddlex/official_models/PaddleOCR-VL/config.json
# Loading weights file /Users/tak/.paddlex/official_models/PaddleOCR-VL/model.safetensors
# use GQA - num_heads: 16- num_key_value_heads: 2
# use GQA - num_heads: 16- num_key_value_heads: 2
# use GQA - num_heads: 16- num_key_value_heads: 2
# use GQA - num_heads: 16- num_key_value_heads: 2
# use GQA - num_heads: 16- num_key_value_heads: 2
# use GQA - num_heads: 16- num_key_value_heads: 2
# use GQA - num_heads: 16- num_key_value_heads: 2
# use GQA - num_heads: 16- num_key_value_heads: 2
# ...
